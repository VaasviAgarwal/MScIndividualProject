# %% [markdown]
# # **Installation of Libraries**
# The libraries are downloaded to be used in the audio intervention under the project
# 1. Assembly AI - Assembly AI has been downloaded to work in transcribing the audio files
# 2. Pydub - This library is installed to be used as a means to split the audio files into smaller segments

# %%
pip install assemblyai
# Out:
# Collecting assemblyai
#   Downloading assemblyai-0.31.0-py3-none-any.whl.metadata (27 kB)
# Collecting httpx>=0.19.0 (from assemblyai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic!=1.10.7,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from assemblyai) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7 in /usr/local/lib/python3.10/dist-packages (from assemblyai) (4.12.2)
# Collecting websockets>=11.0 (from assemblyai)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (2024.7.4)
# Collecting httpcore==1.* (from httpx>=0.19.0->assemblyai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.19.0->assemblyai) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.19.0->assemblyai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.10.7,>=1.7.0->assemblyai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.10.7,>=1.7.0->assemblyai) (2.20.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.19.0->assemblyai) (1.2.2)
# Downloading assemblyai-0.31.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 3.1 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.7 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: websockets, h11, httpcore, httpx, assemblyai
# Successfully installed assemblyai-0.31.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 websockets-12.0

# %%
pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %% [markdown]
# # **Splitting the audio**

# %% [markdown]
# Splitting of audio of "Our Planet - Frozen Worlds" by David Attenborough

# %%
import os
from pydub import AudioSegment
import math

def split_audio(audio_file):

    audio = AudioSegment.from_file(audio_file)

    #Segment length is 15 seconds
    segment_length = 15 * 1000

    total_duration = len(audio)

    # Finding the number of segments to be created based on the length of the audio and the
    num_segments = math.ceil(total_duration / segment_length)

    base_name = os.path.splitext(os.path.basename(audio_file))[0]

    # Creating a folder to save the split audios
    output_dir = os.path.join(os.path.dirname(audio_file), base_name)
    os.makedirs(output_dir, exist_ok=True)

    # Splitting the audio into num_segments segments
    for i in range(num_segments):
        start_time = i * segment_length
        end_time = min((i + 1) * segment_length, total_duration)
        segment = audio[start_time:end_time]
        #Adding the segment to the required folder
        segment.export(os.path.join(output_dir, f"Part{i+1}.mp3"), format="mp3")

if __name__ == "__main__":

    #Audio File name
    audio_file = "OurPlanet-FrozenWorlds.mp3"
    split_audio(audio_file)

# %% [markdown]
# Splitting of audiobook of "The Magic Shop" by H. G. Wells

# %%
import os
from pydub import AudioSegment
import math

def split_audio(audio_file):

    audio = AudioSegment.from_file(audio_file)

    #Segment length is 15 seconds
    segment_length = 15 * 1000

    total_duration = len(audio)

    # Finding the number of segments to be created based on the length of the audio and the
    num_segments = math.ceil(total_duration / segment_length)

    base_name = os.path.splitext(os.path.basename(audio_file))[0]

    # Creating a folder to save the split audios
    output_dir = os.path.join(os.path.dirname(audio_file), base_name)
    os.makedirs(output_dir, exist_ok=True)

    # Splitting the audio into num_segments segments
    for i in range(num_segments):
        start_time = i * segment_length
        end_time = min((i + 1) * segment_length, total_duration)
        segment = audio[start_time:end_time]

        segment.export(os.path.join(output_dir, f"Part{i+1}.mp3"), format="mp3")

if __name__ == "__main__":

    #Audio File name
    audio_file = "TheMagicShop.mp3"
    split_audio(audio_file)

# %% [markdown]
# # **Transcribing the audio**

# %% [markdown]
# Transcribing the 15 second segments of audio of "Our Planet - Frozen Worlds" by David Attenborough

# %%
import os
import assemblyai as aai

aai.settings.api_key = "YOUR_API_KEY"

def transcribe_and_save(folder_path):

    #for every audio file segment in the folder associated with that audio, we get a .txt file with its transcription with the same name
    for filename in os.listdir(folder_path):

        #looking for audio files
        if filename.endswith('.mp3'):

            #Getting paths of each audio file
            file_path = os.path.join(folder_path, filename)

            #Creating a .txt file related to that particular audio
            output_file = os.path.splitext(file_path)[0] + ".txt"

            #Getting the transcription of the audio file
            config = aai.TranscriptionConfig(
                summarization=True,
                summary_model=aai.SummarizationModel.informative,
                summary_type=aai.SummarizationType.bullets
            )
            transcript = aai.Transcriber().transcribe(file_path, config)
            if transcript.status == aai.TranscriptStatus.error:
                print(f"Error transcribing {filename}: {transcript.error}")
            else:

                #Saving the transcription received as text in the correct .txt file
                with open(output_file, 'w') as f:
                    f.write(f"{transcript.text}")
                print(f"Transcription saved to {output_file}")

if __name__ == "__main__":
    folder_path = "OurPlanet-FrozenWorlds"
    transcribe_and_save(folder_path)
    print("All transcriptions saved.")
# Out:
# Transcription saved to OurPlanet-FrozenWorlds/Part172.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part184.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part103.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part140.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part28.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part42.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part213.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part88.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part38.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part89.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part125.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part166.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part132.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part81.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part61.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part143.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part189.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part17.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part206.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part97.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part147.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part153.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part120.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part95.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part113.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part124.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part211.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part202.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part192.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part183.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part159.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part205.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part59.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part12.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part107.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part164.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part156.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part158.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part212.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part196.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part204.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part47.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part208.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part18.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part46.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part128.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part106.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part146.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part133.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part203.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part182.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part22.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part66.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part139.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part215.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part56.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part135.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part100.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part194.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part101.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part25.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part154.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part155.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part157.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part26.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part65.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part180.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part90.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part87.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part32.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part41.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part119.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part31.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part39.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part30.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part127.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part16.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part148.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part175.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part35.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part173.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part150.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part58.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part149.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part115.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part83.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part67.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part171.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part96.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part40.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part36.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part109.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part73.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part6.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part126.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part160.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part104.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part144.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part193.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part187.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part130.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part145.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part174.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part15.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part191.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part52.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part82.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part10.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part176.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part72.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part50.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part76.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part210.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part79.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part112.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part85.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part199.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part99.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part1.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part190.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part70.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part185.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part92.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part201.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part195.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part200.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part21.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part45.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part9.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part75.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part51.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part207.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part181.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part84.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part169.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part151.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part20.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part186.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part33.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part77.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part117.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part34.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part209.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part91.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part13.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part27.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part54.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part24.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part114.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part188.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part60.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part123.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part141.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part11.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part43.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part86.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part62.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part49.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part4.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part122.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part121.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part23.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part179.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part19.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part94.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part137.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part178.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part198.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part14.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part80.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part165.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part78.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part48.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part138.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part129.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part5.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part110.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part142.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part53.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part2.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part197.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part177.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part134.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part152.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part57.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part69.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part108.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part29.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part163.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part7.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part111.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part105.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part55.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part44.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part214.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part71.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part3.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part93.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part162.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part102.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part167.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part131.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part64.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part168.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part63.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part68.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part170.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part118.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part136.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part116.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part74.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part37.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part8.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part161.txt
# Transcription saved to OurPlanet-FrozenWorlds/Part98.txt
# All transcriptions saved.

# %% [markdown]
# Transcribing the 15 second segments of audiobook of "The Magic Shop" by H. G. Wells

# %%
import os
import assemblyai as aai

#API key for Assembly AI that gives us 1000 minutes of transcription
aai.settings.api_key = "YOUR_API_KEY"

def transcribe_and_save(folder_path):

    #for every audio file segment in the folder associated with that audio, we get a .txt file with its transcription with the same name
    for filename in os.listdir(folder_path):

        #looking for audio files
        if filename.endswith('.mp3'):

            #Getting paths of each audio file
            file_path = os.path.join(folder_path, filename)

            #Creating a .txt file related to that particular audio
            output_file = os.path.splitext(file_path)[0] + ".txt"

            #Getting the transcription of the audio file
            config = aai.TranscriptionConfig(
                summarization=True,
                summary_model=aai.SummarizationModel.informative,
                summary_type=aai.SummarizationType.bullets
            )
            transcript = aai.Transcriber().transcribe(file_path, config)
            if transcript.status == aai.TranscriptStatus.error:
                print(f"Error transcribing {filename}: {transcript.error}")
            else:

                #Saving the transcription received as text in the correct .txt file
                with open(output_file, 'w') as f:
                    f.write(f"{transcript.text}")
                print(f"Transcription saved to {output_file}")

if __name__ == "__main__":
    folder_path = "TheMagicShop"
    transcribe_and_save(folder_path)
    print("All transcriptions saved.")
# Out:
# Transcription saved to TheMagicShop/Part103.txt
# Transcription saved to TheMagicShop/Part28.txt
# Transcription saved to TheMagicShop/Part42.txt
# Transcription saved to TheMagicShop/Part88.txt
# Transcription saved to TheMagicShop/Part38.txt
# Transcription saved to TheMagicShop/Part89.txt
# Transcription saved to TheMagicShop/Part81.txt
# Transcription saved to TheMagicShop/Part61.txt
# Transcription saved to TheMagicShop/Part17.txt
# Transcription saved to TheMagicShop/Part97.txt
# Transcription saved to TheMagicShop/Part95.txt
# Transcription saved to TheMagicShop/Part59.txt
# Transcription saved to TheMagicShop/Part12.txt
# Transcription saved to TheMagicShop/Part107.txt
# Transcription saved to TheMagicShop/Part47.txt
# Transcription saved to TheMagicShop/Part18.txt
# Transcription saved to TheMagicShop/Part46.txt
# Transcription saved to TheMagicShop/Part106.txt
# Transcription saved to TheMagicShop/Part22.txt
# Transcription saved to TheMagicShop/Part66.txt
# Transcription saved to TheMagicShop/Part56.txt
# Transcription saved to TheMagicShop/Part100.txt
# Transcription saved to TheMagicShop/Part101.txt
# Transcription saved to TheMagicShop/Part25.txt
# Transcription saved to TheMagicShop/Part26.txt
# Transcription saved to TheMagicShop/Part65.txt
# Transcription saved to TheMagicShop/Part90.txt
# Transcription saved to TheMagicShop/Part87.txt
# Transcription saved to TheMagicShop/Part32.txt
# Transcription saved to TheMagicShop/Part41.txt
# Transcription saved to TheMagicShop/Part31.txt
# Transcription saved to TheMagicShop/Part39.txt
# Transcription saved to TheMagicShop/Part30.txt
# Transcription saved to TheMagicShop/Part16.txt
# Transcription saved to TheMagicShop/Part35.txt
# Transcription saved to TheMagicShop/Part58.txt
# Transcription saved to TheMagicShop/Part83.txt
# Transcription saved to TheMagicShop/Part67.txt
# Transcription saved to TheMagicShop/Part96.txt
# Transcription saved to TheMagicShop/Part40.txt
# Transcription saved to TheMagicShop/Part36.txt
# Transcription saved to TheMagicShop/Part109.txt
# Transcription saved to TheMagicShop/Part73.txt
# Transcription saved to TheMagicShop/Part6.txt
# Transcription saved to TheMagicShop/Part104.txt
# Transcription saved to TheMagicShop/Part15.txt
# Transcription saved to TheMagicShop/Part52.txt
# Transcription saved to TheMagicShop/Part82.txt
# Transcription saved to TheMagicShop/Part10.txt
# Transcription saved to TheMagicShop/Part72.txt
# Transcription saved to TheMagicShop/Part50.txt
# Transcription saved to TheMagicShop/Part76.txt
# Transcription saved to TheMagicShop/Part79.txt
# Transcription saved to TheMagicShop/Part85.txt
# Transcription saved to TheMagicShop/Part99.txt
# Transcription saved to TheMagicShop/Part1.txt
# Transcription saved to TheMagicShop/Part70.txt
# Transcription saved to TheMagicShop/Part92.txt
# Transcription saved to TheMagicShop/Part21.txt
# Transcription saved to TheMagicShop/Part45.txt
# Transcription saved to TheMagicShop/Part9.txt
# Transcription saved to TheMagicShop/Part75.txt
# Transcription saved to TheMagicShop/Part51.txt
# Transcription saved to TheMagicShop/Part84.txt
# Transcription saved to TheMagicShop/Part20.txt
# Transcription saved to TheMagicShop/Part33.txt
# Transcription saved to TheMagicShop/Part77.txt
# Transcription saved to TheMagicShop/Part34.txt
# Transcription saved to TheMagicShop/Part91.txt
# Transcription saved to TheMagicShop/Part13.txt
# Transcription saved to TheMagicShop/Part27.txt
# Transcription saved to TheMagicShop/Part54.txt
# Transcription saved to TheMagicShop/Part24.txt
# Transcription saved to TheMagicShop/Part60.txt
# Transcription saved to TheMagicShop/Part11.txt
# Transcription saved to TheMagicShop/Part43.txt
# Transcription saved to TheMagicShop/Part86.txt
# Transcription saved to TheMagicShop/Part62.txt
# Transcription saved to TheMagicShop/Part49.txt
# Transcription saved to TheMagicShop/Part4.txt
# Transcription saved to TheMagicShop/Part23.txt
# Transcription saved to TheMagicShop/Part19.txt
# Transcription saved to TheMagicShop/Part94.txt
# Transcription saved to TheMagicShop/Part14.txt
# Transcription saved to TheMagicShop/Part80.txt
# Transcription saved to TheMagicShop/Part78.txt
# Transcription saved to TheMagicShop/Part48.txt
# Transcription saved to TheMagicShop/Part5.txt
# Transcription saved to TheMagicShop/Part53.txt
# Transcription saved to TheMagicShop/Part2.txt
# Transcription saved to TheMagicShop/Part57.txt
# Transcription saved to TheMagicShop/Part69.txt
# Transcription saved to TheMagicShop/Part108.txt
# Transcription saved to TheMagicShop/Part29.txt
# Transcription saved to TheMagicShop/Part7.txt
# Transcription saved to TheMagicShop/Part105.txt
# Transcription saved to TheMagicShop/Part55.txt
# Transcription saved to TheMagicShop/Part44.txt
# Transcription saved to TheMagicShop/Part71.txt
# Transcription saved to TheMagicShop/Part3.txt
# Transcription saved to TheMagicShop/Part93.txt
# Transcription saved to TheMagicShop/Part102.txt
# Transcription saved to TheMagicShop/Part64.txt
# Transcription saved to TheMagicShop/Part63.txt
# Transcription saved to TheMagicShop/Part68.txt
# Transcription saved to TheMagicShop/Part74.txt
# Transcription saved to TheMagicShop/Part37.txt
# Transcription saved to TheMagicShop/Part8.txt
# Transcription saved to TheMagicShop/Part98.txt
# All transcriptions saved.

# %% [markdown]
# # **Deleting the segmented audios**

# %% [markdown]
# Deleting the 15 second segments of audio of "Our Planet - Frozen Worlds" by David Attenborough and keeping only the transcriptions

# %%
import os

def delete_mp3(folder):

    #Running code for each file in the given folder
    for filename in os.listdir(folder):

        #Looking for files that have the extension .mp3
        if filename.endswith('.mp3'):
            file_path = os.path.join(folder, filename)

            #Deleting the .mp3 file (15 second segment of the audio)
            os.remove(file_path)
            print(f"Deleted {file_path}")

if __name__ == "__main__":
    folder = "OurPlanet-FrozenWorlds"
    delete_mp3(folder)
    print("All .mp3 files deleted.")
# Out:
# Deleted OurPlanet-FrozenWorlds/Part172.mp3
# Deleted OurPlanet-FrozenWorlds/Part184.mp3
# Deleted OurPlanet-FrozenWorlds/Part103.mp3
# Deleted OurPlanet-FrozenWorlds/Part140.mp3
# Deleted OurPlanet-FrozenWorlds/Part28.mp3
# Deleted OurPlanet-FrozenWorlds/Part42.mp3
# Deleted OurPlanet-FrozenWorlds/Part213.mp3
# Deleted OurPlanet-FrozenWorlds/Part88.mp3
# Deleted OurPlanet-FrozenWorlds/Part38.mp3
# Deleted OurPlanet-FrozenWorlds/Part89.mp3
# Deleted OurPlanet-FrozenWorlds/Part125.mp3
# Deleted OurPlanet-FrozenWorlds/Part166.mp3
# Deleted OurPlanet-FrozenWorlds/Part132.mp3
# Deleted OurPlanet-FrozenWorlds/Part81.mp3
# Deleted OurPlanet-FrozenWorlds/Part61.mp3
# Deleted OurPlanet-FrozenWorlds/Part143.mp3
# Deleted OurPlanet-FrozenWorlds/Part189.mp3
# Deleted OurPlanet-FrozenWorlds/Part17.mp3
# Deleted OurPlanet-FrozenWorlds/Part206.mp3
# Deleted OurPlanet-FrozenWorlds/Part97.mp3
# Deleted OurPlanet-FrozenWorlds/Part147.mp3
# Deleted OurPlanet-FrozenWorlds/Part153.mp3
# Deleted OurPlanet-FrozenWorlds/Part120.mp3
# Deleted OurPlanet-FrozenWorlds/Part95.mp3
# Deleted OurPlanet-FrozenWorlds/Part113.mp3
# Deleted OurPlanet-FrozenWorlds/Part124.mp3
# Deleted OurPlanet-FrozenWorlds/Part211.mp3
# Deleted OurPlanet-FrozenWorlds/Part202.mp3
# Deleted OurPlanet-FrozenWorlds/Part192.mp3
# Deleted OurPlanet-FrozenWorlds/Part183.mp3
# Deleted OurPlanet-FrozenWorlds/Part159.mp3
# Deleted OurPlanet-FrozenWorlds/Part205.mp3
# Deleted OurPlanet-FrozenWorlds/Part59.mp3
# Deleted OurPlanet-FrozenWorlds/Part12.mp3
# Deleted OurPlanet-FrozenWorlds/Part107.mp3
# Deleted OurPlanet-FrozenWorlds/Part164.mp3
# Deleted OurPlanet-FrozenWorlds/Part156.mp3
# Deleted OurPlanet-FrozenWorlds/Part158.mp3
# Deleted OurPlanet-FrozenWorlds/Part212.mp3
# Deleted OurPlanet-FrozenWorlds/Part196.mp3
# Deleted OurPlanet-FrozenWorlds/Part204.mp3
# Deleted OurPlanet-FrozenWorlds/Part47.mp3
# Deleted OurPlanet-FrozenWorlds/Part208.mp3
# Deleted OurPlanet-FrozenWorlds/Part18.mp3
# Deleted OurPlanet-FrozenWorlds/Part46.mp3
# Deleted OurPlanet-FrozenWorlds/Part128.mp3
# Deleted OurPlanet-FrozenWorlds/Part106.mp3
# Deleted OurPlanet-FrozenWorlds/Part146.mp3
# Deleted OurPlanet-FrozenWorlds/Part133.mp3
# Deleted OurPlanet-FrozenWorlds/Part203.mp3
# Deleted OurPlanet-FrozenWorlds/Part182.mp3
# Deleted OurPlanet-FrozenWorlds/Part22.mp3
# Deleted OurPlanet-FrozenWorlds/Part66.mp3
# Deleted OurPlanet-FrozenWorlds/Part139.mp3
# Deleted OurPlanet-FrozenWorlds/Part215.mp3
# Deleted OurPlanet-FrozenWorlds/Part56.mp3
# Deleted OurPlanet-FrozenWorlds/Part135.mp3
# Deleted OurPlanet-FrozenWorlds/Part100.mp3
# Deleted OurPlanet-FrozenWorlds/Part194.mp3
# Deleted OurPlanet-FrozenWorlds/Part101.mp3
# Deleted OurPlanet-FrozenWorlds/Part25.mp3
# Deleted OurPlanet-FrozenWorlds/Part154.mp3
# Deleted OurPlanet-FrozenWorlds/Part155.mp3
# Deleted OurPlanet-FrozenWorlds/Part157.mp3
# Deleted OurPlanet-FrozenWorlds/Part26.mp3
# Deleted OurPlanet-FrozenWorlds/Part65.mp3
# Deleted OurPlanet-FrozenWorlds/Part180.mp3
# Deleted OurPlanet-FrozenWorlds/Part90.mp3
# Deleted OurPlanet-FrozenWorlds/Part87.mp3
# Deleted OurPlanet-FrozenWorlds/Part32.mp3
# Deleted OurPlanet-FrozenWorlds/Part41.mp3
# Deleted OurPlanet-FrozenWorlds/Part119.mp3
# Deleted OurPlanet-FrozenWorlds/Part31.mp3
# Deleted OurPlanet-FrozenWorlds/Part39.mp3
# Deleted OurPlanet-FrozenWorlds/Part30.mp3
# Deleted OurPlanet-FrozenWorlds/Part127.mp3
# Deleted OurPlanet-FrozenWorlds/Part16.mp3
# Deleted OurPlanet-FrozenWorlds/Part148.mp3
# Deleted OurPlanet-FrozenWorlds/Part175.mp3
# Deleted OurPlanet-FrozenWorlds/Part35.mp3
# Deleted OurPlanet-FrozenWorlds/Part173.mp3
# Deleted OurPlanet-FrozenWorlds/Part150.mp3
# Deleted OurPlanet-FrozenWorlds/Part58.mp3
# Deleted OurPlanet-FrozenWorlds/Part149.mp3
# Deleted OurPlanet-FrozenWorlds/Part115.mp3
# Deleted OurPlanet-FrozenWorlds/Part83.mp3
# Deleted OurPlanet-FrozenWorlds/Part67.mp3
# Deleted OurPlanet-FrozenWorlds/Part171.mp3
# Deleted OurPlanet-FrozenWorlds/Part96.mp3
# Deleted OurPlanet-FrozenWorlds/Part40.mp3
# Deleted OurPlanet-FrozenWorlds/Part36.mp3
# Deleted OurPlanet-FrozenWorlds/Part109.mp3
# Deleted OurPlanet-FrozenWorlds/Part73.mp3
# Deleted OurPlanet-FrozenWorlds/Part6.mp3
# Deleted OurPlanet-FrozenWorlds/Part126.mp3
# Deleted OurPlanet-FrozenWorlds/Part160.mp3
# Deleted OurPlanet-FrozenWorlds/Part104.mp3
# Deleted OurPlanet-FrozenWorlds/Part144.mp3
# Deleted OurPlanet-FrozenWorlds/Part193.mp3
# Deleted OurPlanet-FrozenWorlds/Part187.mp3
# Deleted OurPlanet-FrozenWorlds/Part130.mp3
# Deleted OurPlanet-FrozenWorlds/Part145.mp3
# Deleted OurPlanet-FrozenWorlds/Part174.mp3
# Deleted OurPlanet-FrozenWorlds/Part15.mp3
# Deleted OurPlanet-FrozenWorlds/Part191.mp3
# Deleted OurPlanet-FrozenWorlds/Part52.mp3
# Deleted OurPlanet-FrozenWorlds/Part82.mp3
# Deleted OurPlanet-FrozenWorlds/Part10.mp3
# Deleted OurPlanet-FrozenWorlds/Part176.mp3
# Deleted OurPlanet-FrozenWorlds/Part72.mp3
# Deleted OurPlanet-FrozenWorlds/Part50.mp3
# Deleted OurPlanet-FrozenWorlds/Part76.mp3
# Deleted OurPlanet-FrozenWorlds/Part210.mp3
# Deleted OurPlanet-FrozenWorlds/Part79.mp3
# Deleted OurPlanet-FrozenWorlds/Part112.mp3
# Deleted OurPlanet-FrozenWorlds/Part85.mp3
# Deleted OurPlanet-FrozenWorlds/Part199.mp3
# Deleted OurPlanet-FrozenWorlds/Part99.mp3
# Deleted OurPlanet-FrozenWorlds/Part1.mp3
# Deleted OurPlanet-FrozenWorlds/Part190.mp3
# Deleted OurPlanet-FrozenWorlds/Part70.mp3
# Deleted OurPlanet-FrozenWorlds/Part185.mp3
# Deleted OurPlanet-FrozenWorlds/Part92.mp3
# Deleted OurPlanet-FrozenWorlds/Part201.mp3
# Deleted OurPlanet-FrozenWorlds/Part195.mp3
# Deleted OurPlanet-FrozenWorlds/Part200.mp3
# Deleted OurPlanet-FrozenWorlds/Part21.mp3
# Deleted OurPlanet-FrozenWorlds/Part45.mp3
# Deleted OurPlanet-FrozenWorlds/Part9.mp3
# Deleted OurPlanet-FrozenWorlds/Part75.mp3
# Deleted OurPlanet-FrozenWorlds/Part51.mp3
# Deleted OurPlanet-FrozenWorlds/Part207.mp3
# Deleted OurPlanet-FrozenWorlds/Part181.mp3
# Deleted OurPlanet-FrozenWorlds/Part84.mp3
# Deleted OurPlanet-FrozenWorlds/Part169.mp3
# Deleted OurPlanet-FrozenWorlds/Part151.mp3
# Deleted OurPlanet-FrozenWorlds/Part20.mp3
# Deleted OurPlanet-FrozenWorlds/Part186.mp3
# Deleted OurPlanet-FrozenWorlds/Part33.mp3
# Deleted OurPlanet-FrozenWorlds/Part77.mp3
# Deleted OurPlanet-FrozenWorlds/Part117.mp3
# Deleted OurPlanet-FrozenWorlds/Part34.mp3
# Deleted OurPlanet-FrozenWorlds/Part209.mp3
# Deleted OurPlanet-FrozenWorlds/Part91.mp3
# Deleted OurPlanet-FrozenWorlds/Part13.mp3
# Deleted OurPlanet-FrozenWorlds/Part27.mp3
# Deleted OurPlanet-FrozenWorlds/Part54.mp3
# Deleted OurPlanet-FrozenWorlds/Part24.mp3
# Deleted OurPlanet-FrozenWorlds/Part114.mp3
# Deleted OurPlanet-FrozenWorlds/Part188.mp3
# Deleted OurPlanet-FrozenWorlds/Part60.mp3
# Deleted OurPlanet-FrozenWorlds/Part123.mp3
# Deleted OurPlanet-FrozenWorlds/Part141.mp3
# Deleted OurPlanet-FrozenWorlds/Part11.mp3
# Deleted OurPlanet-FrozenWorlds/Part43.mp3
# Deleted OurPlanet-FrozenWorlds/Part86.mp3
# Deleted OurPlanet-FrozenWorlds/Part62.mp3
# Deleted OurPlanet-FrozenWorlds/Part49.mp3
# Deleted OurPlanet-FrozenWorlds/Part4.mp3
# Deleted OurPlanet-FrozenWorlds/Part122.mp3
# Deleted OurPlanet-FrozenWorlds/Part121.mp3
# Deleted OurPlanet-FrozenWorlds/Part23.mp3
# Deleted OurPlanet-FrozenWorlds/Part179.mp3
# Deleted OurPlanet-FrozenWorlds/Part19.mp3
# Deleted OurPlanet-FrozenWorlds/Part94.mp3
# Deleted OurPlanet-FrozenWorlds/Part137.mp3
# Deleted OurPlanet-FrozenWorlds/Part178.mp3
# Deleted OurPlanet-FrozenWorlds/Part198.mp3
# Deleted OurPlanet-FrozenWorlds/Part14.mp3
# Deleted OurPlanet-FrozenWorlds/Part80.mp3
# Deleted OurPlanet-FrozenWorlds/Part165.mp3
# Deleted OurPlanet-FrozenWorlds/Part78.mp3
# Deleted OurPlanet-FrozenWorlds/Part48.mp3
# Deleted OurPlanet-FrozenWorlds/Part138.mp3
# Deleted OurPlanet-FrozenWorlds/Part129.mp3
# Deleted OurPlanet-FrozenWorlds/Part5.mp3
# Deleted OurPlanet-FrozenWorlds/Part110.mp3
# Deleted OurPlanet-FrozenWorlds/Part142.mp3
# Deleted OurPlanet-FrozenWorlds/Part53.mp3
# Deleted OurPlanet-FrozenWorlds/Part2.mp3
# Deleted OurPlanet-FrozenWorlds/Part197.mp3
# Deleted OurPlanet-FrozenWorlds/Part177.mp3
# Deleted OurPlanet-FrozenWorlds/Part134.mp3
# Deleted OurPlanet-FrozenWorlds/Part152.mp3
# Deleted OurPlanet-FrozenWorlds/Part57.mp3
# Deleted OurPlanet-FrozenWorlds/Part69.mp3
# Deleted OurPlanet-FrozenWorlds/Part108.mp3
# Deleted OurPlanet-FrozenWorlds/Part29.mp3
# Deleted OurPlanet-FrozenWorlds/Part163.mp3
# Deleted OurPlanet-FrozenWorlds/Part7.mp3
# Deleted OurPlanet-FrozenWorlds/Part111.mp3
# Deleted OurPlanet-FrozenWorlds/Part105.mp3
# Deleted OurPlanet-FrozenWorlds/Part55.mp3
# Deleted OurPlanet-FrozenWorlds/Part44.mp3
# Deleted OurPlanet-FrozenWorlds/Part214.mp3
# Deleted OurPlanet-FrozenWorlds/Part71.mp3
# Deleted OurPlanet-FrozenWorlds/Part3.mp3
# Deleted OurPlanet-FrozenWorlds/Part93.mp3
# Deleted OurPlanet-FrozenWorlds/Part162.mp3
# Deleted OurPlanet-FrozenWorlds/Part102.mp3
# Deleted OurPlanet-FrozenWorlds/Part167.mp3
# Deleted OurPlanet-FrozenWorlds/Part131.mp3
# Deleted OurPlanet-FrozenWorlds/Part64.mp3
# Deleted OurPlanet-FrozenWorlds/Part168.mp3
# Deleted OurPlanet-FrozenWorlds/Part63.mp3
# Deleted OurPlanet-FrozenWorlds/Part68.mp3
# Deleted OurPlanet-FrozenWorlds/Part170.mp3
# Deleted OurPlanet-FrozenWorlds/Part118.mp3
# Deleted OurPlanet-FrozenWorlds/Part136.mp3
# Deleted OurPlanet-FrozenWorlds/Part116.mp3
# Deleted OurPlanet-FrozenWorlds/Part74.mp3
# Deleted OurPlanet-FrozenWorlds/Part37.mp3
# Deleted OurPlanet-FrozenWorlds/Part8.mp3
# Deleted OurPlanet-FrozenWorlds/Part161.mp3
# Deleted OurPlanet-FrozenWorlds/Part98.mp3
# All .mp3 files deleted.

# %% [markdown]
# Deleting the 15 second segments of audiobook of "The Magic Shop" by H. G. Wells and keeping only the transcriptions

# %%
import os

def delete_mp3(folder):

    #Running code for each file in the given folder
    for filename in os.listdir(folder):

        #Looking for files that have the extension .mp3
        if filename.endswith('.mp3'):
            file_path = os.path.join(folder, filename)

            #Deleting the .mp3 file (15 second segment of the audio)
            os.remove(file_path)
            print(f"Deleted {file_path}")

if __name__ == "__main__":
    folder = "TheMagicShop"
    delete_mp3(folder)
    print("All .mp3 files deleted.")
# Out:
# Deleted TheMagicShop/Part103.mp3
# Deleted TheMagicShop/Part28.mp3
# Deleted TheMagicShop/Part42.mp3
# Deleted TheMagicShop/Part88.mp3
# Deleted TheMagicShop/Part38.mp3
# Deleted TheMagicShop/Part89.mp3
# Deleted TheMagicShop/Part81.mp3
# Deleted TheMagicShop/Part61.mp3
# Deleted TheMagicShop/Part17.mp3
# Deleted TheMagicShop/Part97.mp3
# Deleted TheMagicShop/Part95.mp3
# Deleted TheMagicShop/Part59.mp3
# Deleted TheMagicShop/Part12.mp3
# Deleted TheMagicShop/Part107.mp3
# Deleted TheMagicShop/Part47.mp3
# Deleted TheMagicShop/Part18.mp3
# Deleted TheMagicShop/Part46.mp3
# Deleted TheMagicShop/Part106.mp3
# Deleted TheMagicShop/Part22.mp3
# Deleted TheMagicShop/Part66.mp3
# Deleted TheMagicShop/Part56.mp3
# Deleted TheMagicShop/Part100.mp3
# Deleted TheMagicShop/Part101.mp3
# Deleted TheMagicShop/Part25.mp3
# Deleted TheMagicShop/Part26.mp3
# Deleted TheMagicShop/Part65.mp3
# Deleted TheMagicShop/Part90.mp3
# Deleted TheMagicShop/Part87.mp3
# Deleted TheMagicShop/Part32.mp3
# Deleted TheMagicShop/Part41.mp3
# Deleted TheMagicShop/Part31.mp3
# Deleted TheMagicShop/Part39.mp3
# Deleted TheMagicShop/Part30.mp3
# Deleted TheMagicShop/Part16.mp3
# Deleted TheMagicShop/Part35.mp3
# Deleted TheMagicShop/Part58.mp3
# Deleted TheMagicShop/Part83.mp3
# Deleted TheMagicShop/Part67.mp3
# Deleted TheMagicShop/Part96.mp3
# Deleted TheMagicShop/Part40.mp3
# Deleted TheMagicShop/Part36.mp3
# Deleted TheMagicShop/Part109.mp3
# Deleted TheMagicShop/Part73.mp3
# Deleted TheMagicShop/Part6.mp3
# Deleted TheMagicShop/Part104.mp3
# Deleted TheMagicShop/Part15.mp3
# Deleted TheMagicShop/Part52.mp3
# Deleted TheMagicShop/Part82.mp3
# Deleted TheMagicShop/Part10.mp3
# Deleted TheMagicShop/Part72.mp3
# Deleted TheMagicShop/Part50.mp3
# Deleted TheMagicShop/Part76.mp3
# Deleted TheMagicShop/Part79.mp3
# Deleted TheMagicShop/Part85.mp3
# Deleted TheMagicShop/Part99.mp3
# Deleted TheMagicShop/Part1.mp3
# Deleted TheMagicShop/Part70.mp3
# Deleted TheMagicShop/Part92.mp3
# Deleted TheMagicShop/Part21.mp3
# Deleted TheMagicShop/Part45.mp3
# Deleted TheMagicShop/Part9.mp3
# Deleted TheMagicShop/Part75.mp3
# Deleted TheMagicShop/Part51.mp3
# Deleted TheMagicShop/Part84.mp3
# Deleted TheMagicShop/Part20.mp3
# Deleted TheMagicShop/Part33.mp3
# Deleted TheMagicShop/Part77.mp3
# Deleted TheMagicShop/Part34.mp3
# Deleted TheMagicShop/Part91.mp3
# Deleted TheMagicShop/Part13.mp3
# Deleted TheMagicShop/Part27.mp3
# Deleted TheMagicShop/Part54.mp3
# Deleted TheMagicShop/Part24.mp3
# Deleted TheMagicShop/Part60.mp3
# Deleted TheMagicShop/Part11.mp3
# Deleted TheMagicShop/Part43.mp3
# Deleted TheMagicShop/Part86.mp3
# Deleted TheMagicShop/Part62.mp3
# Deleted TheMagicShop/Part49.mp3
# Deleted TheMagicShop/Part4.mp3
# Deleted TheMagicShop/Part23.mp3
# Deleted TheMagicShop/Part19.mp3
# Deleted TheMagicShop/Part94.mp3
# Deleted TheMagicShop/Part14.mp3
# Deleted TheMagicShop/Part80.mp3
# Deleted TheMagicShop/Part78.mp3
# Deleted TheMagicShop/Part48.mp3
# Deleted TheMagicShop/Part5.mp3
# Deleted TheMagicShop/Part53.mp3
# Deleted TheMagicShop/Part2.mp3
# Deleted TheMagicShop/Part57.mp3
# Deleted TheMagicShop/Part69.mp3
# Deleted TheMagicShop/Part108.mp3
# Deleted TheMagicShop/Part29.mp3
# Deleted TheMagicShop/Part7.mp3
# Deleted TheMagicShop/Part105.mp3
# Deleted TheMagicShop/Part55.mp3
# Deleted TheMagicShop/Part44.mp3
# Deleted TheMagicShop/Part71.mp3
# Deleted TheMagicShop/Part3.mp3
# Deleted TheMagicShop/Part93.mp3
# Deleted TheMagicShop/Part102.mp3
# Deleted TheMagicShop/Part64.mp3
# Deleted TheMagicShop/Part63.mp3
# Deleted TheMagicShop/Part68.mp3
# Deleted TheMagicShop/Part74.mp3
# Deleted TheMagicShop/Part37.mp3
# Deleted TheMagicShop/Part8.mp3
# Deleted TheMagicShop/Part98.mp3
# All .mp3 files deleted.

# %% [markdown]
# # **Downloading the folder**

# %% [markdown]
# Creating a .zip file of the folder with only the transcriptions of the 15 second segments of audio of "Our Planet - Frozen Worlds" by David Attenborough and downloading it from google.colab

# %%
from google.colab import files
import shutil

folder = "OurPlanet-FrozenWorlds"
output_file = "OurPlanet-FrozenWorlds.zip"

# Zipping the given folder
shutil.make_archive(output_file.replace('.zip', ''), 'zip', folder)

# Downloading the zipped file to the computer
files.download(output_file)

# %% [markdown]
# Creating a .zip file of the folder with only the transcriptions of the 15 second segments of audio of "The Magic Shop" by H. G. Wells and downloading it from google.colab

# %%
from google.colab import files
import shutil

folder = "TheMagicShop"
output_file = "TheMagicShop.zip"

# Zipping the given folder
shutil.make_archive(output_file.replace('.zip', ''), 'zip', folder)

# Downloading the zipped file to the computer
files.download(output_file)
